# %%
#Task 1 Solution
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000,90.000,size=1500)
lngs = np.random.uniform(-180.000, 180.000,size=1500)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
        city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
        # If the city is unique, then we will add it to the cities list.
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 1500

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=874420077e6feaade6650c8200445dc8

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if(i%50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count+=1


# Run an API request for each of the cities.
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["main"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #Get rain or snow details if present
        try:
            if city_weather_description == 'Rain':
                city_rain = city_weather['rain']['3h']
            else:
                city_rain = 0
        except:
            print("No rain attribute found")
        
        try:
            if city_weather_description == 'Snow':
                city_snow = city_weather['snow']['3h']
            else:
                city_snow = 0
        except:
            print("No snow attribute found")
            
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Rain inches(last 3hrs)":city_rain,
                          "Snow inches(last 3hrs)":city_snow,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ballina
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | yellowknife
# No snow attribute found
# Processing Record 10 of Set 1 | yumen
# Processing Record 11 of Set 1 | menongue
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | otorohanga
# Processing Record 14 of Set 1 | road town
# Processing Record 15 of Set 1 | bonga
# Processing Record 16 of Set 1 | beringovskiy
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | taoudenni
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | pisco
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | pudozh
# Processing Record 29 of Set 1 | sorong
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | talnakh
# No snow attribute found
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | alugan
# Processing Record 36 of Set 1 | manavgat
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | calama
# Processing Record 43 of Set 1 | katsuura
# No rain attribute found
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | ossora
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | norman wells
# No snow attribute found
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | valparaiso
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | pangnirtung
# No snow attribute found
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | nuevo progreso
# Processing Record 6 of Set 2 | varhaug
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | nanchong
# Processing Record 9 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | cherskiy
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | hilo
# No rain attribute found
# Processing Record 14 of Set 2 | te anau
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | usinsk
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | cockburn town
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | gongzhuling
# Processing Record 35 of Set 2 | quelimane
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | takoradi
# Processing Record 38 of Set 2 | minab
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | mushie
# Processing Record 41 of Set 2 | ilo
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | sola
# Processing Record 45 of Set 2 | buena vista
# Processing Record 46 of Set 2 | sola
# Processing Record 47 of Set 2 | borogontsy
# Processing Record 48 of Set 2 | rikitea
# Processing Record 49 of Set 2 | wanning
# Processing Record 50 of Set 2 | hilo
# No rain attribute found
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | uribia
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | hilo
# No rain attribute found
# Processing Record 5 of Set 3 | juegang
# Processing Record 6 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | burkhala
# City not found. Skipping...
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | pakhtakoron
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | rikitea
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | opuwo
# Processing Record 17 of Set 3 | great yarmouth
# Processing Record 18 of Set 3 | davila
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | longyearbyen
# No snow attribute found
# Processing Record 23 of Set 3 | ushuaia
# Processing Record 24 of Set 3 | caconda
# Processing Record 25 of Set 3 | tazovskiy
# Processing Record 26 of Set 3 | rikitea
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | havelock
# Processing Record 30 of Set 3 | busselton
# Processing Record 31 of Set 3 | busselton
# Processing Record 32 of Set 3 | skelleftea
# Processing Record 33 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 3 | deoria
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | harper
# Processing Record 37 of Set 3 | busselton
# Processing Record 38 of Set 3 | sibolga
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | rawson
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | broome
# No rain attribute found
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | talnakh
# No snow attribute found
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | qaanaaq
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | ushuaia
# Processing Record 50 of Set 3 | hobart
# Processing Record 1 of Set 4 | nioro
# Processing Record 2 of Set 4 | new norfolk
# Processing Record 3 of Set 4 | cabra
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | san rafael
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | rikitea
# Processing Record 8 of Set 4 | ushuaia
# Processing Record 9 of Set 4 | kapaa
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | lima
# Processing Record 12 of Set 4 | hobart
# Processing Record 13 of Set 4 | vaini
# Processing Record 14 of Set 4 | stow
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | balkhash
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | bilibino
# Processing Record 19 of Set 4 | vieques
# No rain attribute found
# Processing Record 20 of Set 4 | port lincoln
# Processing Record 21 of Set 4 | mogadishu
# Processing Record 22 of Set 4 | mataura
# Processing Record 23 of Set 4 | punta arenas
# Processing Record 24 of Set 4 | nabha
# Processing Record 25 of Set 4 | rikitea
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | batagay
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | rikitea
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | athabasca
# Processing Record 32 of Set 4 | rikitea
# Processing Record 33 of Set 4 | busselton
# Processing Record 34 of Set 4 | gizo
# Processing Record 35 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 4 | olga
# Processing Record 37 of Set 4 | saskylakh
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | rikitea
# Processing Record 40 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 4 | mataura
# Processing Record 42 of Set 4 | uusikaupunki
# Processing Record 43 of Set 4 | guarda
# Processing Record 44 of Set 4 | bluff
# Processing Record 45 of Set 4 | trabzon
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | kapaa
# Processing Record 48 of Set 4 | hongjiang
# Processing Record 49 of Set 4 | sonoita
# Processing Record 50 of Set 4 | havoysund
# Processing Record 1 of Set 5 | bambous virieux
# Processing Record 2 of Set 5 | rikitea
# Processing Record 3 of Set 5 | rikitea
# Processing Record 4 of Set 5 | punta arenas
# Processing Record 5 of Set 5 | mataura
# Processing Record 6 of Set 5 | puerto ayora
# Processing Record 7 of Set 5 | saldanha
# Processing Record 8 of Set 5 | itumbiara
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | provideniya
# No snow attribute found
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | toora-khem
# Processing Record 13 of Set 5 | accra
# Processing Record 14 of Set 5 | fukue
# Processing Record 15 of Set 5 | bredasdorp
# Processing Record 16 of Set 5 | nikolskoye
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | qaanaaq
# Processing Record 19 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 5 | vaini
# Processing Record 21 of Set 5 | sidi ali
# Processing Record 22 of Set 5 | ushuaia
# Processing Record 23 of Set 5 | pisco
# Processing Record 24 of Set 5 | erenhot
# Processing Record 25 of Set 5 | santa vitoria do palmar
# Processing Record 26 of Set 5 | alice springs
# Processing Record 27 of Set 5 | punta arenas
# Processing Record 28 of Set 5 | carnarvon
# Processing Record 29 of Set 5 | albany
# Processing Record 30 of Set 5 | rikitea
# Processing Record 31 of Set 5 | meulaboh
# Processing Record 32 of Set 5 | busselton
# Processing Record 33 of Set 5 | doha
# Processing Record 34 of Set 5 | ushuaia
# Processing Record 35 of Set 5 | vaini
# Processing Record 36 of Set 5 | sur
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | borama
# City not found. Skipping...
# Processing Record 40 of Set 5 | barra
# Processing Record 41 of Set 5 | bowen
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | casablanca
# Processing Record 44 of Set 5 | ushuaia
# Processing Record 45 of Set 5 | albany
# Processing Record 46 of Set 5 | bluff
# Processing Record 47 of Set 5 | yellowknife
# No snow attribute found
# Processing Record 48 of Set 5 | rikitea
# Processing Record 49 of Set 5 | kapaa
# Processing Record 50 of Set 5 | simao
# Processing Record 1 of Set 6 | new norfolk
# Processing Record 2 of Set 6 | saint anthony
# Processing Record 3 of Set 6 | punta arenas
# Processing Record 4 of Set 6 | ayolas
# Processing Record 5 of Set 6 | busselton
# Processing Record 6 of Set 6 | esperance
# Processing Record 7 of Set 6 | butaritari
# Processing Record 8 of Set 6 | atuona
# Processing Record 9 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 6 | fortuna
# Processing Record 11 of Set 6 | newberry
# Processing Record 12 of Set 6 | thompson
# No snow attribute found
# Processing Record 13 of Set 6 | busselton
# Processing Record 14 of Set 6 | mataura
# Processing Record 15 of Set 6 | busselton
# Processing Record 16 of Set 6 | upernavik
# Processing Record 17 of Set 6 | ribeira grande
# Processing Record 18 of Set 6 | nabire
# Processing Record 19 of Set 6 | hithadhoo
# Processing Record 20 of Set 6 | thompson
# No snow attribute found
# Processing Record 21 of Set 6 | ponta do sol
# Processing Record 22 of Set 6 | jiangyou
# Processing Record 23 of Set 6 | new norfolk
# Processing Record 24 of Set 6 | lorengau
# Processing Record 25 of Set 6 | trinidad
# Processing Record 26 of Set 6 | general pico
# Processing Record 27 of Set 6 | albany
# Processing Record 28 of Set 6 | jurm
# Processing Record 29 of Set 6 | kapaa
# Processing Record 30 of Set 6 | kismayo
# Processing Record 31 of Set 6 | hobart
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | cape town
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | khatanga
# Processing Record 36 of Set 6 | rio cuarto
# Processing Record 37 of Set 6 | dunedin
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | busselton
# Processing Record 40 of Set 6 | jamestown
# Processing Record 41 of Set 6 | kiama
# Processing Record 42 of Set 6 | hasaki
# Processing Record 43 of Set 6 | punta arenas
# Processing Record 44 of Set 6 | otjiwarongo
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | la tuque
# Processing Record 47 of Set 6 | jamestown
# Processing Record 48 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | qaqortoq
# Processing Record 50 of Set 6 | busselton
# Processing Record 1 of Set 7 | hue
# Processing Record 2 of Set 7 | pyatnitskoye
# Processing Record 3 of Set 7 | methoni
# No rain attribute found
# Processing Record 4 of Set 7 | gagnoa
# Processing Record 5 of Set 7 | souillac
# Processing Record 6 of Set 7 | georgetown
# Processing Record 7 of Set 7 | teguldet
# Processing Record 8 of Set 7 | southbridge
# No rain attribute found
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | nyurba
# Processing Record 11 of Set 7 | avarua
# Processing Record 12 of Set 7 | busselton
# Processing Record 13 of Set 7 | norman wells
# No snow attribute found
# Processing Record 14 of Set 7 | bambous virieux
# Processing Record 15 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 7 | salalah
# Processing Record 17 of Set 7 | muros
# Processing Record 18 of Set 7 | porto novo
# Processing Record 19 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 7 | bluff
# Processing Record 21 of Set 7 | agar
# Processing Record 22 of Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | ushuaia
# Processing Record 25 of Set 7 | berlevag
# Processing Record 26 of Set 7 | kapaa
# Processing Record 27 of Set 7 | wilson
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | koumra
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | rikitea
# Processing Record 32 of Set 7 | mataura
# Processing Record 33 of Set 7 | manokwari
# Processing Record 34 of Set 7 | acapulco
# Processing Record 35 of Set 7 | punta arenas
# Processing Record 36 of Set 7 | necochea
# Processing Record 37 of Set 7 | maldonado
# Processing Record 38 of Set 7 | rikitea
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | bambous virieux
# Processing Record 41 of Set 7 | tonota
# Processing Record 42 of Set 7 | albany
# Processing Record 43 of Set 7 | velsk
# Processing Record 44 of Set 7 | tasiilaq
# Processing Record 45 of Set 7 | launceston
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | huarmey
# Processing Record 48 of Set 7 | saint george
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | arraial do cabo
# Processing Record 1 of Set 8 | ushuaia
# Processing Record 2 of Set 8 | burnie
# Processing Record 3 of Set 8 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 8 | upernavik
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | cape town
# Processing Record 7 of Set 8 | riberalta
# Processing Record 8 of Set 8 | kamaishi
# No rain attribute found
# Processing Record 9 of Set 8 | dukat
# Processing Record 10 of Set 8 | tasiilaq
# Processing Record 11 of Set 8 | new norfolk
# Processing Record 12 of Set 8 | victoria
# Processing Record 13 of Set 8 | sibiti
# Processing Record 14 of Set 8 | mar del plata
# Processing Record 15 of Set 8 | mataura
# Processing Record 16 of Set 8 | punta arenas
# Processing Record 17 of Set 8 | phrai bung
# City not found. Skipping...
# Processing Record 18 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | luganville
# Processing Record 20 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 8 | maragogi
# Processing Record 22 of Set 8 | bagdarin
# Processing Record 23 of Set 8 | castro
# Processing Record 24 of Set 8 | kruisfontein
# Processing Record 25 of Set 8 | beringovskiy
# Processing Record 26 of Set 8 | stokmarknes
# Processing Record 27 of Set 8 | ushuaia
# Processing Record 28 of Set 8 | busselton
# Processing Record 29 of Set 8 | cherskiy
# Processing Record 30 of Set 8 | saskylakh
# Processing Record 31 of Set 8 | albany
# Processing Record 32 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 8 | vaini
# Processing Record 35 of Set 8 | hithadhoo
# Processing Record 36 of Set 8 | ushuaia
# Processing Record 37 of Set 8 | menongue
# Processing Record 38 of Set 8 | savasleyka
# Processing Record 39 of Set 8 | sobolevo
# Processing Record 40 of Set 8 | lasa
# Processing Record 41 of Set 8 | katsuura
# No rain attribute found
# Processing Record 42 of Set 8 | mataura
# Processing Record 43 of Set 8 | busselton
# Processing Record 44 of Set 8 | atagay
# Processing Record 45 of Set 8 | kaitangata
# Processing Record 46 of Set 8 | nome
# Processing Record 47 of Set 8 | vardo
# Processing Record 48 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 49 of Set 8 | kiama
# Processing Record 50 of Set 8 | wanning
# Processing Record 1 of Set 9 | rikitea
# Processing Record 2 of Set 9 | teya
# Processing Record 3 of Set 9 | ponta do sol
# Processing Record 4 of Set 9 | krasnyy chikoy
# Processing Record 5 of Set 9 | salinopolis
# Processing Record 6 of Set 9 | villena
# Processing Record 7 of Set 9 | saint-philippe
# Processing Record 8 of Set 9 | hilo
# No rain attribute found
# Processing Record 9 of Set 9 | diu
# Processing Record 10 of Set 9 | nanortalik
# Processing Record 11 of Set 9 | hilo
# No rain attribute found
# Processing Record 12 of Set 9 | avarua
# Processing Record 13 of Set 9 | kapaa
# Processing Record 14 of Set 9 | bredasdorp
# Processing Record 15 of Set 9 | kerrville
# Processing Record 16 of Set 9 | vargem alta
# Processing Record 17 of Set 9 | busselton
# Processing Record 18 of Set 9 | vila velha
# No rain attribute found
# Processing Record 19 of Set 9 | north berwick
# Processing Record 20 of Set 9 | jamestown
# Processing Record 21 of Set 9 | mar del plata
# Processing Record 22 of Set 9 | saskylakh
# Processing Record 23 of Set 9 | tuktoyaktuk
# Processing Record 24 of Set 9 | dustlik
# Processing Record 25 of Set 9 | thompson
# No snow attribute found
# Processing Record 26 of Set 9 | cidreira
# Processing Record 27 of Set 9 | roald
# Processing Record 28 of Set 9 | atuona
# Processing Record 29 of Set 9 | kaitangata
# Processing Record 30 of Set 9 | busselton
# Processing Record 31 of Set 9 | nikolskoye
# Processing Record 32 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 9 | ilulissat
# Processing Record 35 of Set 9 | albany
# Processing Record 36 of Set 9 | kavieng
# Processing Record 37 of Set 9 | ushuaia
# Processing Record 38 of Set 9 | jamestown
# Processing Record 39 of Set 9 | avarua
# Processing Record 40 of Set 9 | punta arenas
# Processing Record 41 of Set 9 | muisne
# Processing Record 42 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 9 | ostersund
# No snow attribute found
# Processing Record 44 of Set 9 | esperance
# Processing Record 45 of Set 9 | mahebourg
# Processing Record 46 of Set 9 | khandyga
# Processing Record 47 of Set 9 | saint george
# Processing Record 48 of Set 9 | hilo
# No rain attribute found
# Processing Record 49 of Set 9 | butaritari
# Processing Record 50 of Set 9 | ilulissat
# Processing Record 1 of Set 10 | ushuaia
# Processing Record 2 of Set 10 | pevek
# Processing Record 3 of Set 10 | vaini
# Processing Record 4 of Set 10 | aswan
# Processing Record 5 of Set 10 | port blair
# Processing Record 6 of Set 10 | punta arenas
# Processing Record 7 of Set 10 | tuktoyaktuk
# Processing Record 8 of Set 10 | dingzhou
# Processing Record 9 of Set 10 | rikitea
# Processing Record 10 of Set 10 | badvel
# Processing Record 11 of Set 10 | isangel
# Processing Record 12 of Set 10 | prince rupert
# Processing Record 13 of Set 10 | rostusa
# Processing Record 14 of Set 10 | luderitz
# Processing Record 15 of Set 10 | rikitea
# Processing Record 16 of Set 10 | jamestown
# Processing Record 17 of Set 10 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 10 | busselton
# Processing Record 19 of Set 10 | port elizabeth
# Processing Record 20 of Set 10 | yulara
# Processing Record 21 of Set 10 | dzhebariki-khaya
# Processing Record 22 of Set 10 | butaritari
# Processing Record 23 of Set 10 | cidreira
# Processing Record 24 of Set 10 | rikitea
# Processing Record 25 of Set 10 | khatanga
# Processing Record 26 of Set 10 | mount isa
# No rain attribute found
# Processing Record 27 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 10 | provideniya
# No snow attribute found
# Processing Record 29 of Set 10 | klyuchi
# Processing Record 30 of Set 10 | portland
# Processing Record 31 of Set 10 | ushuaia
# Processing Record 32 of Set 10 | kodiak
# Processing Record 33 of Set 10 | arraial do cabo
# Processing Record 34 of Set 10 | ushuaia
# Processing Record 35 of Set 10 | port elizabeth
# Processing Record 36 of Set 10 | mataura
# Processing Record 37 of Set 10 | varberg
# Processing Record 38 of Set 10 | nikolskoye
# Processing Record 39 of Set 10 | atuona
# Processing Record 40 of Set 10 | port alfred
# Processing Record 41 of Set 10 | hermanus
# Processing Record 42 of Set 10 | ramnagar
# Processing Record 43 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 10 | albany
# Processing Record 45 of Set 10 | ormara
# Processing Record 46 of Set 10 | atuona
# Processing Record 47 of Set 10 | kavaratti
# Processing Record 48 of Set 10 | arraial do cabo
# Processing Record 49 of Set 10 | rikitea
# Processing Record 50 of Set 10 | vestmanna
# Processing Record 1 of Set 11 | hobart
# Processing Record 2 of Set 11 | iberia
# Processing Record 3 of Set 11 | pacific grove
# Processing Record 4 of Set 11 | san cristobal
# Processing Record 5 of Set 11 | jalu
# Processing Record 6 of Set 11 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 11 | scarborough
# Processing Record 8 of Set 11 | bathsheba
# Processing Record 9 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 11 | east london
# Processing Record 11 of Set 11 | coquimbo
# Processing Record 12 of Set 11 | saint-augustin
# Processing Record 13 of Set 11 | tuatapere
# Processing Record 14 of Set 11 | tasiilaq
# Processing Record 15 of Set 11 | mar del plata
# Processing Record 16 of Set 11 | punta arenas
# Processing Record 17 of Set 11 | ejido
# Processing Record 18 of Set 11 | geraldton
# Processing Record 19 of Set 11 | zhangye
# Processing Record 20 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 11 | cabo san lucas
# Processing Record 22 of Set 11 | punta arenas
# Processing Record 23 of Set 11 | albany
# Processing Record 24 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 11 | krasnaya gora
# Processing Record 26 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 11 | kapaa
# Processing Record 28 of Set 11 | punta arenas
# Processing Record 29 of Set 11 | koindu
# Processing Record 30 of Set 11 | broken hill
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | kumluca
# Processing Record 33 of Set 11 | albany
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | puerto ayora
# Processing Record 36 of Set 11 | mahebourg
# Processing Record 37 of Set 11 | pandan
# Processing Record 38 of Set 11 | nanortalik
# Processing Record 39 of Set 11 | hermanus
# Processing Record 40 of Set 11 | dikson
# Processing Record 41 of Set 11 | arraial do cabo
# Processing Record 42 of Set 11 | ushuaia
# Processing Record 43 of Set 11 | lasa
# Processing Record 44 of Set 11 | chinhoyi
# Processing Record 45 of Set 11 | ushuaia
# Processing Record 46 of Set 11 | jamestown
# Processing Record 47 of Set 11 | altayskoye
# Processing Record 48 of Set 11 | barrow
# Processing Record 49 of Set 11 | severo-kurilsk
# Processing Record 50 of Set 11 | kelo
# Processing Record 1 of Set 12 | rikitea
# Processing Record 2 of Set 12 | albany
# Processing Record 3 of Set 12 | rikitea
# Processing Record 4 of Set 12 | vestmannaeyjar
# Processing Record 5 of Set 12 | yellowknife
# No snow attribute found
# Processing Record 6 of Set 12 | kavieng
# Processing Record 7 of Set 12 | ilulissat
# Processing Record 8 of Set 12 | kachiry
# Processing Record 9 of Set 12 | zhangjiakou
# Processing Record 10 of Set 12 | chokurdakh
# Processing Record 11 of Set 12 | hamilton
# Processing Record 12 of Set 12 | ushuaia
# Processing Record 13 of Set 12 | tuktoyaktuk
# Processing Record 14 of Set 12 | pangnirtung
# No snow attribute found
# Processing Record 15 of Set 12 | rikitea
# Processing Record 16 of Set 12 | kulachi
# Processing Record 17 of Set 12 | thompson
# No snow attribute found
# Processing Record 18 of Set 12 | morondava
# Processing Record 19 of Set 12 | fukue
# Processing Record 20 of Set 12 | agadez
# Processing Record 21 of Set 12 | henties bay
# Processing Record 22 of Set 12 | rundu
# Processing Record 23 of Set 12 | saint-philippe
# Processing Record 24 of Set 12 | meckenbeuren
# Processing Record 25 of Set 12 | mahanoro
# Processing Record 26 of Set 12 | itaueira
# Processing Record 27 of Set 12 | rikitea
# Processing Record 28 of Set 12 | mataura
# Processing Record 29 of Set 12 | punta arenas
# Processing Record 30 of Set 12 | antalaha
# Processing Record 31 of Set 12 | ola
# Processing Record 32 of Set 12 | busselton
# Processing Record 33 of Set 12 | carnarvon
# Processing Record 34 of Set 12 | rikitea
# Processing Record 35 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 12 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 12 | punta arenas
# Processing Record 39 of Set 12 | richards bay
# Processing Record 40 of Set 12 | lakatoro
# Processing Record 41 of Set 12 | srandakan
# Processing Record 42 of Set 12 | toyooka
# Processing Record 43 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 12 | cururupu
# Processing Record 45 of Set 12 | rikitea
# Processing Record 46 of Set 12 | mataura
# Processing Record 47 of Set 12 | cidreira
# Processing Record 48 of Set 12 | slyudyanka
# Processing Record 49 of Set 12 | vaini
# Processing Record 50 of Set 12 | hasaki
# Processing Record 1 of Set 13 | kysyl-syr
# Processing Record 2 of Set 13 | vaini
# Processing Record 3 of Set 13 | forbes
# Processing Record 4 of Set 13 | necochea
# Processing Record 5 of Set 13 | ushuaia
# Processing Record 6 of Set 13 | saint-pierre
# Processing Record 7 of Set 13 | kodiak
# Processing Record 8 of Set 13 | vaini
# Processing Record 9 of Set 13 | faanui
# Processing Record 10 of Set 13 | belmonte
# Processing Record 11 of Set 13 | luderitz
# Processing Record 12 of Set 13 | hualmay
# Processing Record 13 of Set 13 | esperance
# Processing Record 14 of Set 13 | mitsamiouli
# Processing Record 15 of Set 13 | ushuaia
# Processing Record 16 of Set 13 | rikitea
# Processing Record 17 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 13 | provideniya
# No snow attribute found
# Processing Record 19 of Set 13 | zunheboto
# Processing Record 20 of Set 13 | atuona
# Processing Record 21 of Set 13 | hithadhoo
# Processing Record 22 of Set 13 | eyl
# Processing Record 23 of Set 13 | acapulco
# Processing Record 24 of Set 13 | rawson
# Processing Record 25 of Set 13 | punta arenas
# Processing Record 26 of Set 13 | jamestown
# Processing Record 27 of Set 13 | teguldet
# Processing Record 28 of Set 13 | tiksi
# Processing Record 29 of Set 13 | shubarshi
# Processing Record 30 of Set 13 | iqaluit
# No snow attribute found
# Processing Record 31 of Set 13 | hobart
# Processing Record 32 of Set 13 | bredasdorp
# Processing Record 33 of Set 13 | tuktoyaktuk
# Processing Record 34 of Set 13 | vaini
# Processing Record 35 of Set 13 | husavik
# Processing Record 36 of Set 13 | bethel
# No rain attribute found
# Processing Record 37 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 13 | castro
# Processing Record 39 of Set 13 | albany
# Processing Record 40 of Set 13 | punta arenas
# Processing Record 41 of Set 13 | ushuaia
# Processing Record 42 of Set 13 | albany
# Processing Record 43 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 13 | barra do garcas
# Processing Record 45 of Set 13 | vaini
# Processing Record 46 of Set 13 | ushuaia
# Processing Record 47 of Set 13 | qaanaaq
# Processing Record 48 of Set 13 | mahebourg
# Processing Record 49 of Set 13 | porto velho
# Processing Record 50 of Set 13 | bredasdorp
# Processing Record 1 of Set 14 | palimbang
# Processing Record 2 of Set 14 | meulaboh
# Processing Record 3 of Set 14 | savalou
# Processing Record 4 of Set 14 | severo-kurilsk
# Processing Record 5 of Set 14 | kapaa
# Processing Record 6 of Set 14 | jamestown
# Processing Record 7 of Set 14 | busselton
# Processing Record 8 of Set 14 | sambava
# Processing Record 9 of Set 14 | hermanus
# Processing Record 10 of Set 14 | ovsyanka
# Processing Record 11 of Set 14 | olafsvik
# Processing Record 12 of Set 14 | guerrero negro
# Processing Record 13 of Set 14 | bengkulu
# Processing Record 14 of Set 14 | qasigiannguit
# Processing Record 15 of Set 14 | olafsvik
# Processing Record 16 of Set 14 | albany
# Processing Record 17 of Set 14 | dalvik
# Processing Record 18 of Set 14 | rikitea
# Processing Record 19 of Set 14 | georgetown
# Processing Record 20 of Set 14 | saskylakh
# Processing Record 21 of Set 14 | dikson
# Processing Record 22 of Set 14 | dikson
# Processing Record 23 of Set 14 | saint-philippe
# Processing Record 24 of Set 14 | ushuaia
# Processing Record 25 of Set 14 | pore
# Processing Record 26 of Set 14 | abu zabad
# Processing Record 27 of Set 14 | yerbogachen
# Processing Record 28 of Set 14 | bangassou
# Processing Record 29 of Set 14 | makakilo city
# Processing Record 30 of Set 14 | ulagan
# Processing Record 31 of Set 14 | erice
# Processing Record 32 of Set 14 | zhanaozen
# Processing Record 33 of Set 14 | saint-philippe
# Processing Record 34 of Set 14 | ushuaia
# Processing Record 35 of Set 14 | evensk
# Processing Record 36 of Set 14 | mataura
# Processing Record 37 of Set 14 | klaksvik
# Processing Record 38 of Set 14 | severo-kurilsk
# Processing Record 39 of Set 14 | mar del plata
# Processing Record 40 of Set 14 | ushuaia
# Processing Record 41 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 14 | kuching
# Processing Record 43 of Set 14 | northam
# Processing Record 44 of Set 14 | cherskiy
# Processing Record 45 of Set 14 | kaitangata
# Processing Record 46 of Set 14 | nantucket
# No rain attribute found
# Processing Record 47 of Set 14 | englehart
# Processing Record 48 of Set 14 | yumen
# Processing Record 49 of Set 14 | saratov
# Processing Record 50 of Set 14 | rikitea
# Processing Record 1 of Set 15 | port alfred
# Processing Record 2 of Set 15 | albany
# Processing Record 3 of Set 15 | puerto ayora
# Processing Record 4 of Set 15 | mataura
# Processing Record 5 of Set 15 | obo
# Processing Record 6 of Set 15 | mataura
# Processing Record 7 of Set 15 | saint-francois
# Processing Record 8 of Set 15 | kavaratti
# Processing Record 9 of Set 15 | rikitea
# Processing Record 10 of Set 15 | vila velha
# No rain attribute found
# Processing Record 11 of Set 15 | rikitea
# Processing Record 12 of Set 15 | erzin
# Processing Record 13 of Set 15 | ribeira grande
# Processing Record 14 of Set 15 | ponta do sol
# Processing Record 15 of Set 15 | zaysan
# Processing Record 16 of Set 15 | avarua
# Processing Record 17 of Set 15 | tura
# Processing Record 18 of Set 15 | cape town
# Processing Record 19 of Set 15 | bubaque
# Processing Record 20 of Set 15 | georgetown
# Processing Record 21 of Set 15 | barrow
# Processing Record 22 of Set 15 | natal
# Processing Record 23 of Set 15 | ocos
# Processing Record 24 of Set 15 | nanortalik
# Processing Record 25 of Set 15 | norman wells
# No snow attribute found
# Processing Record 26 of Set 15 | isangel
# Processing Record 27 of Set 15 | tirlyanskiy
# Processing Record 28 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 15 | san patricio
# Processing Record 30 of Set 15 | yellowknife
# No snow attribute found
# Processing Record 31 of Set 15 | isangel
# Processing Record 32 of Set 15 | barrow
# Processing Record 33 of Set 15 | nikolskoye
# Processing Record 34 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 15 | karratha
# Processing Record 36 of Set 15 | caravelas
# Processing Record 37 of Set 15 | kapaa
# Processing Record 38 of Set 15 | norman wells
# No snow attribute found
# Processing Record 39 of Set 15 | busselton
# Processing Record 40 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 15 | bluff
# Processing Record 42 of Set 15 | pochutla
# Processing Record 43 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 15 | los llanos de aridane
# Processing Record 45 of Set 15 | yenagoa
# Processing Record 46 of Set 15 | rikitea
# Processing Record 47 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 15 | belmonte
# Processing Record 49 of Set 15 | jamestown
# Processing Record 50 of Set 15 | albany
# Processing Record 1 of Set 16 | kapaa
# Processing Record 2 of Set 16 | albany
# Processing Record 3 of Set 16 | qandala
# Processing Record 4 of Set 16 | busselton
# Processing Record 5 of Set 16 | provideniya
# No snow attribute found
# Processing Record 6 of Set 16 | vao
# Processing Record 7 of Set 16 | berlevag
# Processing Record 8 of Set 16 | urfa
# City not found. Skipping...
# Processing Record 9 of Set 16 | yulara
# Processing Record 10 of Set 16 | olafsvik
# Processing Record 11 of Set 16 | progreso
# Processing Record 12 of Set 16 | cravo norte
# Processing Record 13 of Set 16 | whitehorse
# No snow attribute found
# Processing Record 14 of Set 16 | bluff
# Processing Record 15 of Set 16 | saint anthony
# Processing Record 16 of Set 16 | carnarvon
# Processing Record 17 of Set 16 | nanortalik
# Processing Record 18 of Set 16 | taltal
# Processing Record 19 of Set 16 | qaanaaq
# Processing Record 20 of Set 16 | hobart
# Processing Record 21 of Set 16 | ponta do sol
# Processing Record 22 of Set 16 | barrow
# Processing Record 23 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 16 | cape town
# Processing Record 25 of Set 16 | qaanaaq
# Processing Record 26 of Set 16 | rikitea
# Processing Record 27 of Set 16 | dikson
# Processing Record 28 of Set 16 | mataura
# Processing Record 29 of Set 16 | talnakh
# No snow attribute found
# Processing Record 30 of Set 16 | cidreira
# Processing Record 31 of Set 16 | bluff
# Processing Record 32 of Set 16 | faanui
# Processing Record 33 of Set 16 | cape town
# Processing Record 34 of Set 16 | san buenaventura
# Processing Record 35 of Set 16 | visconde do rio branco
# Processing Record 36 of Set 16 | kapaa
# Processing Record 37 of Set 16 | bethel
# No rain attribute found
# Processing Record 38 of Set 16 | gamba
# Processing Record 39 of Set 16 | esperance
# Processing Record 40 of Set 16 | ucluelet
# No rain attribute found
# Processing Record 41 of Set 16 | ushuaia
# Processing Record 42 of Set 16 | cidreira
# Processing Record 43 of Set 16 | mataura
# Processing Record 44 of Set 16 | ushuaia
# Processing Record 45 of Set 16 | mikuni
# No rain attribute found
# Processing Record 46 of Set 16 | qandala
# Processing Record 47 of Set 16 | rock sound
# Processing Record 48 of Set 16 | luanda
# Processing Record 49 of Set 16 | mataura
# Processing Record 50 of Set 16 | arraial do cabo
# Processing Record 1 of Set 17 | mahebourg
# Processing Record 2 of Set 17 | lethem
# Processing Record 3 of Set 17 | bluff
# Processing Record 4 of Set 17 | hilo
# No rain attribute found
# Processing Record 5 of Set 17 | butaritari
# Processing Record 6 of Set 17 | vaini
# Processing Record 7 of Set 17 | yangjiang
# Processing Record 8 of Set 17 | tuktoyaktuk
# Processing Record 9 of Set 17 | along
# Processing Record 10 of Set 17 | khurba
# Processing Record 11 of Set 17 | kichera
# Processing Record 12 of Set 17 | east london
# Processing Record 13 of Set 17 | clyde river
# Processing Record 14 of Set 17 | bethel
# No rain attribute found
# Processing Record 15 of Set 17 | rapar
# Processing Record 16 of Set 17 | new norfolk
# Processing Record 17 of Set 17 | avarua
# Processing Record 18 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 17 | saskylakh
# Processing Record 20 of Set 17 | souillac
# Processing Record 21 of Set 17 | shima
# Processing Record 22 of Set 17 | mataura
# Processing Record 23 of Set 17 | basco
# Processing Record 24 of Set 17 | telenesti
# Processing Record 25 of Set 17 | raga
# Processing Record 26 of Set 17 | atuona
# Processing Record 27 of Set 17 | hobart
# Processing Record 28 of Set 17 | vardo
# Processing Record 29 of Set 17 | airai
# Processing Record 30 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 17 | maloshuyka
# City not found. Skipping...
# Processing Record 32 of Set 17 | chokurdakh
# Processing Record 33 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 17 | rikitea
# Processing Record 35 of Set 17 | bluff
# Processing Record 36 of Set 17 | tres arroyos
# Processing Record 37 of Set 17 | kapaa
# Processing Record 38 of Set 17 | khatanga
# Processing Record 39 of Set 17 | ancud
# Processing Record 40 of Set 17 | rikitea
# Processing Record 41 of Set 17 | rikitea
# Processing Record 42 of Set 17 | ancud
# Processing Record 43 of Set 17 | huanren
# Processing Record 44 of Set 17 | port alfred
# Processing Record 45 of Set 17 | bengkulu
# Processing Record 46 of Set 17 | saint-francois
# Processing Record 47 of Set 17 | lamego
# Processing Record 48 of Set 17 | chuy
# Processing Record 49 of Set 17 | ushuaia
# Processing Record 50 of Set 17 | kapaa
# Processing Record 1 of Set 18 | karamay
# City not found. Skipping...
# Processing Record 2 of Set 18 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 18 | dunedin
# Processing Record 4 of Set 18 | marabba
# Processing Record 5 of Set 18 | albany
# Processing Record 6 of Set 18 | pangkalanbuun
# Processing Record 7 of Set 18 | sao joao da barra
# Processing Record 8 of Set 18 | khatanga
# Processing Record 9 of Set 18 | kaitangata
# Processing Record 10 of Set 18 | jamestown
# Processing Record 11 of Set 18 | smolenka
# Processing Record 12 of Set 18 | thompson
# No snow attribute found
# Processing Record 13 of Set 18 | kavieng
# Processing Record 14 of Set 18 | kavaratti
# Processing Record 15 of Set 18 | busselton
# Processing Record 16 of Set 18 | marawi
# Processing Record 17 of Set 18 | kaniama
# Processing Record 18 of Set 18 | tiksi
# Processing Record 19 of Set 18 | arraial do cabo
# Processing Record 20 of Set 18 | cape town
# Processing Record 21 of Set 18 | new norfolk
# Processing Record 22 of Set 18 | moerai
# Processing Record 23 of Set 18 | vila
# Processing Record 24 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 18 | albany
# Processing Record 26 of Set 18 | vaini
# Processing Record 27 of Set 18 | pangai
# Processing Record 28 of Set 18 | opatija
# Processing Record 29 of Set 18 | albany
# Processing Record 30 of Set 18 | okandja
# City not found. Skipping...
# Processing Record 31 of Set 18 | nikolskoye
# Processing Record 32 of Set 18 | clyde river
# Processing Record 33 of Set 18 | mataura
# Processing Record 34 of Set 18 | puerto penasco
# Processing Record 35 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 18 | shingu
# No rain attribute found
# Processing Record 37 of Set 18 | hermanus
# Processing Record 38 of Set 18 | punta arenas
# Processing Record 39 of Set 18 | puerto carreno
# Processing Record 40 of Set 18 | kuytun
# Processing Record 41 of Set 18 | mataura
# Processing Record 42 of Set 18 | mahon
# Processing Record 43 of Set 18 | busselton
# Processing Record 44 of Set 18 | banda aceh
# Processing Record 45 of Set 18 | port alfred
# Processing Record 46 of Set 18 | butaritari
# Processing Record 47 of Set 18 | punta arenas
# Processing Record 48 of Set 18 | waitara
# Processing Record 49 of Set 18 | kathu
# Processing Record 50 of Set 18 | ponta do sol
# Processing Record 1 of Set 19 | aykhal
# Processing Record 2 of Set 19 | kapaa
# Processing Record 3 of Set 19 | sweetwater
# Processing Record 4 of Set 19 | kapaa
# Processing Record 5 of Set 19 | bambous virieux
# Processing Record 6 of Set 19 | avarua
# Processing Record 7 of Set 19 | panjakent
# Processing Record 8 of Set 19 | busselton
# Processing Record 9 of Set 19 | marv dasht
# City not found. Skipping...
# Processing Record 10 of Set 19 | east london
# Processing Record 11 of Set 19 | riyadh
# Processing Record 12 of Set 19 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 19 | touros
# Processing Record 14 of Set 19 | puerto ayora
# Processing Record 15 of Set 19 | mount gambier
# Processing Record 16 of Set 19 | cidreira
# Processing Record 17 of Set 19 | avarua
# Processing Record 18 of Set 19 | pacific grove
# Processing Record 19 of Set 19 | arys
# Processing Record 20 of Set 19 | hermanus
# Processing Record 21 of Set 19 | birao
# Processing Record 22 of Set 19 | listvyagi
# Processing Record 23 of Set 19 | ushuaia
# Processing Record 24 of Set 19 | upernavik
# Processing Record 25 of Set 19 | terney
# Processing Record 26 of Set 19 | kapaa
# Processing Record 27 of Set 19 | cape town
# Processing Record 28 of Set 19 | ahipara
# Processing Record 29 of Set 19 | bathsheba
# Processing Record 30 of Set 19 | atuona
# Processing Record 31 of Set 19 | bredasdorp
# Processing Record 32 of Set 19 | barrow
# Processing Record 33 of Set 19 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 19 | vestmannaeyjar
# Processing Record 35 of Set 19 | rikitea
# Processing Record 36 of Set 19 | caninde
# Processing Record 37 of Set 19 | ushuaia
# Processing Record 38 of Set 19 | tilichiki
# Processing Record 39 of Set 19 | lorengau
# Processing Record 40 of Set 19 | chara
# Processing Record 41 of Set 19 | luzilandia
# Processing Record 42 of Set 19 | cascais
# Processing Record 43 of Set 19 | abu jubayhah
# City not found. Skipping...
# Processing Record 44 of Set 19 | myaundzha
# Processing Record 45 of Set 19 | bilibino
# Processing Record 46 of Set 19 | harbour breton
# Processing Record 47 of Set 19 | nhulunbuy
# Processing Record 48 of Set 19 | rikitea
# Processing Record 49 of Set 19 | arlit
# Processing Record 50 of Set 19 | mitchell
# Processing Record 1 of Set 20 | albany
# Processing Record 2 of Set 20 | lebu
# Processing Record 3 of Set 20 | butaritari
# Processing Record 4 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 20 | vaini
# Processing Record 6 of Set 20 | puerto ayora
# Processing Record 7 of Set 20 | caravelas
# Processing Record 8 of Set 20 | port alfred
# Processing Record 9 of Set 20 | busselton
# Processing Record 10 of Set 20 | angoche
# Processing Record 11 of Set 20 | tuktoyaktuk
# Processing Record 12 of Set 20 | bluff
# Processing Record 13 of Set 20 | ambovombe
# Processing Record 14 of Set 20 | fortuna
# Processing Record 15 of Set 20 | muriwai beach
# Processing Record 16 of Set 20 | punta arenas
# Processing Record 17 of Set 20 | vaini
# Processing Record 18 of Set 20 | saskylakh
# Processing Record 19 of Set 20 | qaanaaq
# Processing Record 20 of Set 20 | rikitea
# Processing Record 21 of Set 20 | broome
# No rain attribute found
# Processing Record 22 of Set 20 | victoria
# Processing Record 23 of Set 20 | torbay
# Processing Record 24 of Set 20 | olga
# Processing Record 25 of Set 20 | aktau
# Processing Record 26 of Set 20 | jamestown
# Processing Record 27 of Set 20 | lasa
# Processing Record 28 of Set 20 | waipawa
# Processing Record 29 of Set 20 | longyearbyen
# No snow attribute found
# Processing Record 30 of Set 20 | victoria
# Processing Record 31 of Set 20 | puerto ayora
# Processing Record 32 of Set 20 | qaanaaq
# Processing Record 33 of Set 20 | lorengau
# Processing Record 34 of Set 20 | ponta do sol
# Processing Record 35 of Set 20 | georgetown
# Processing Record 36 of Set 20 | vaini
# Processing Record 37 of Set 20 | inirida
# Processing Record 38 of Set 20 | vao
# Processing Record 39 of Set 20 | saint george
# Processing Record 40 of Set 20 | chapais
# No snow attribute found
# Processing Record 41 of Set 20 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 20 | punta arenas
# Processing Record 43 of Set 20 | albany
# Processing Record 44 of Set 20 | atuona
# Processing Record 45 of Set 20 | arraial do cabo
# Processing Record 46 of Set 20 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 20 | tasiilaq
# Processing Record 48 of Set 20 | rocha
# Processing Record 49 of Set 20 | busselton
# Processing Record 50 of Set 20 | hobart
# Processing Record 1 of Set 21 | ancud
# Processing Record 2 of Set 21 | kruisfontein
# Processing Record 3 of Set 21 | atuona
# Processing Record 4 of Set 21 | altagracia de orituco
# Processing Record 5 of Set 21 | meulaboh
# Processing Record 6 of Set 21 | hithadhoo
# Processing Record 7 of Set 21 | hithadhoo
# Processing Record 8 of Set 21 | norman wells
# No snow attribute found
# Processing Record 9 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 21 | port lincoln
# Processing Record 11 of Set 21 | gilbues
# Processing Record 12 of Set 21 | bluff
# Processing Record 13 of Set 21 | perelyub
# Processing Record 14 of Set 21 | haines junction
# Processing Record 15 of Set 21 | bambous virieux
# Processing Record 16 of Set 21 | port alfred
# Processing Record 17 of Set 21 | pyay
# Processing Record 18 of Set 21 | pyay
# Processing Record 19 of Set 21 | norman wells
# No snow attribute found
# Processing Record 20 of Set 21 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 21 | tual
# Processing Record 22 of Set 21 | vianen
# No rain attribute found
# Processing Record 23 of Set 21 | coquimbo
# Processing Record 24 of Set 21 | bambous virieux
# Processing Record 25 of Set 21 | alofi
# Processing Record 26 of Set 21 | khatanga
# Processing Record 27 of Set 21 | banjar
# Processing Record 28 of Set 21 | husavik
# Processing Record 29 of Set 21 | buzmeyin
# Processing Record 30 of Set 21 | ningyang
# Processing Record 31 of Set 21 | roald
# Processing Record 32 of Set 21 | huilong
# Processing Record 33 of Set 21 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 21 | yambio
# Processing Record 35 of Set 21 | flinders
# Processing Record 36 of Set 21 | byron bay
# No rain attribute found
# Processing Record 37 of Set 21 | vostok
# Processing Record 38 of Set 21 | carnarvon
# Processing Record 39 of Set 21 | fortuna
# Processing Record 40 of Set 21 | pevek
# Processing Record 41 of Set 21 | hobart
# Processing Record 42 of Set 21 | kibakwe
# Processing Record 43 of Set 21 | esperance
# Processing Record 44 of Set 21 | butaritari
# Processing Record 45 of Set 21 | vanderhoof
# Processing Record 46 of Set 21 | hobart
# Processing Record 47 of Set 21 | severo-kurilsk
# Processing Record 48 of Set 21 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 21 | melnikovo
# Processing Record 1 of Set 22 | punta arenas
# Processing Record 2 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 22 | sambava
# Processing Record 4 of Set 22 | hami
# Processing Record 5 of Set 22 | krasnoselkup
# Processing Record 6 of Set 22 | ushuaia
# Processing Record 7 of Set 22 | rikitea
# Processing Record 8 of Set 22 | airai
# Processing Record 9 of Set 22 | avarua
# Processing Record 10 of Set 22 | souillac
# Processing Record 11 of Set 22 | vardo
# Processing Record 12 of Set 22 | port alfred
# ...
# Processing Record 20 of Set 22 | lebu
# Processing Record 21 of Set 22 | ushuaia
# Processing Record 22 of Set 22 | chokurdakh
# Processing Record 23 of Set 22 | anar darreh
# City not found. Skipping...
# Processing Record 24 of Set 22 | new norfolk
# Processing Record 25 of Set 22 | gazanjyk
# Processing Record 26 of Set 22 | pangnirtung
# No snow attribute found
# Processing Record 27 of Set 22 | avera
# Processing Record 28 of Set 22 | marawi
# Processing Record 29 of Set 22 | bengkulu
# Processing Record 30 of Set 22 | vaini
# Processing Record 31 of Set 22 | rikitea
# Processing Record 32 of Set 22 | sayat
# Processing Record 33 of Set 22 | nikolskoye
# Processing Record 34 of Set 22 | sar-e pul
# Processing Record 35 of Set 22 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 22 | hobart
# Processing Record 37 of Set 22 | pavilosta
# Processing Record 38 of Set 22 | saskylakh
# Processing Record 39 of Set 22 | hilo
# No rain attribute found
# Processing Record 40 of Set 22 | bambous virieux
# Processing Record 41 of Set 22 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 22 | mataura
# Processing Record 43 of Set 22 | port alfred
# Processing Record 44 of Set 22 | rikitea
# Processing Record 45 of Set 22 | kaduqli
# Processing Record 46 of Set 22 | oranjemund
# Processing Record 47 of Set 22 | albany
# Processing Record 48 of Set 22 | evensk
# Processing Record 49 of Set 22 | ucluelet
# No rain attribute found
# Processing Record 50 of Set 22 | talara
# Processing Record 1 of Set 23 | barrow
# Processing Record 2 of Set 23 | mount isa
# No rain attribute found
# Processing Record 3 of Set 23 | saint-philippe
# Processing Record 4 of Set 23 | atagay
# Processing Record 5 of Set 23 | rikitea
# Processing Record 6 of Set 23 | rikitea
# Processing Record 7 of Set 23 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 23 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 23 | bethel
# No rain attribute found
# Processing Record 10 of Set 23 | vaini
# Processing Record 11 of Set 23 | kapaa
# Processing Record 12 of Set 23 | lebu
# Processing Record 13 of Set 23 | sioux lookout
# No snow attribute found
# Processing Record 14 of Set 23 | grindavik
# No rain attribute found
# Processing Record 15 of Set 23 | maxixe
# Processing Record 16 of Set 23 | yekaterinoslavka
# Processing Record 17 of Set 23 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 23 | albany
# Processing Record 19 of Set 23 | mitu
# Processing Record 20 of Set 23 | yumaguzino
# Processing Record 21 of Set 23 | ushuaia
# Processing Record 22 of Set 23 | hofn
# Processing Record 23 of Set 23 | hithadhoo
# Processing Record 24 of Set 23 | port lincoln
# Processing Record 25 of Set 23 | busselton
# Processing Record 26 of Set 23 | albany
# Processing Record 27 of Set 23 | hithadhoo
# Processing Record 28 of Set 23 | meulaboh
# Processing Record 29 of Set 23 | busselton
# Processing Record 30 of Set 23 | sibolga
# Processing Record 31 of Set 23 | prince rupert
# Processing Record 32 of Set 23 | jamestown
# Processing Record 33 of Set 23 | mitsamiouli
# Processing Record 34 of Set 23 | ponta do sol
# Processing Record 35 of Set 23 | tasiilaq
# Processing Record 36 of Set 23 | norman wells
# No snow attribute found
# Processing Record 37 of Set 23 | rikitea
# Processing Record 38 of Set 23 | benjamin hill
# Processing Record 39 of Set 23 | homer
# Processing Record 40 of Set 23 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 23 | castro
# Processing Record 42 of Set 23 | vao
# Processing Record 43 of Set 23 | jamestown
# Processing Record 44 of Set 23 | saint-louis
# Processing Record 45 of Set 23 | kayan
# Processing Record 46 of Set 23 | dikson
# Processing Record 47 of Set 23 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 23 | sokoni
# Processing Record 49 of Set 23 | tambacounda
# Processing Record 50 of Set 23 | punto fijo
# Processing Record 1 of Set 24 | mahon
# Processing Record 2 of Set 24 | bay roberts
# Processing Record 3 of Set 24 | qaanaaq
# Processing Record 4 of Set 24 | meulaboh
# Processing Record 5 of Set 24 | nynashamn
# No rain attribute found
# Processing Record 6 of Set 24 | mogadishu
# Processing Record 7 of Set 24 | yellowknife
# No snow attribute found
# Processing Record 8 of Set 24 | hobart
# Processing Record 9 of Set 24 | awbari
# Processing Record 10 of Set 24 | kalaleh
# Processing Record 11 of Set 24 | dikson
# Processing Record 12 of Set 24 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 24 | albany
# Processing Record 14 of Set 24 | cape town
# Processing Record 15 of Set 24 | salalah
# Processing Record 16 of Set 24 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 24 | butaritari
# Processing Record 18 of Set 24 | nouadhibou
# Processing Record 19 of Set 24 | okha
# Processing Record 20 of Set 24 | vaini
# Processing Record 21 of Set 24 | margate
# Processing Record 22 of Set 24 | ponorogo
# Processing Record 23 of Set 24 | punta arenas
# Processing Record 24 of Set 24 | acarau
# Processing Record 25 of Set 24 | vila franca do campo
# No rain attribute found
# Processing Record 26 of Set 24 | ormara
# Processing Record 27 of Set 24 | chokurdakh
# Processing Record 28 of Set 24 | japura
# Processing Record 29 of Set 24 | tasiilaq
# Processing Record 30 of Set 24 | dong hoi
# Processing Record 31 of Set 24 | aulnoye-aymeries
# Processing Record 32 of Set 24 | jamestown
# Processing Record 33 of Set 24 | port keats
# Processing Record 34 of Set 24 | ushuaia
# Processing Record 35 of Set 24 | albany
# Processing Record 36 of Set 24 | sekoma
# Processing Record 37 of Set 24 | pevek
# Processing Record 38 of Set 24 | diego de almagro
# Processing Record 39 of Set 24 | smithers
# No snow attribute found
# Processing Record 40 of Set 24 | bengkulu
# Processing Record 41 of Set 24 | oistins
# Processing Record 42 of Set 24 | rikitea
# Processing Record 43 of Set 24 | mataura
# Processing Record 44 of Set 24 | kuryk
# Processing Record 45 of Set 24 | qaanaaq
# Processing Record 46 of Set 24 | hobart
# Processing Record 47 of Set 24 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 24 | kaiu
# Processing Record 49 of Set 24 | port elizabeth
# Processing Record 50 of Set 24 | qaanaaq
# Processing Record 1 of Set 25 | ushuaia
# Processing Record 2 of Set 25 | yellowknife
# No snow attribute found
# Processing Record 3 of Set 25 | mataura
# Processing Record 4 of Set 25 | yellowknife
# No snow attribute found
# Processing Record 5 of Set 25 | belyy yar
# No snow attribute found
# Processing Record 6 of Set 25 | ushuaia
# Processing Record 7 of Set 25 | xiaolingwei
# Processing Record 8 of Set 25 | constitucion
# Processing Record 9 of Set 25 | saint-philippe
# Processing Record 10 of Set 25 | jamestown
# Processing Record 11 of Set 25 | jamestown
# Processing Record 12 of Set 25 | hithadhoo
# Processing Record 13 of Set 25 | avera
# Processing Record 14 of Set 25 | cape town
# Processing Record 15 of Set 25 | nanortalik
# Processing Record 16 of Set 25 | le port
# Processing Record 17 of Set 25 | ugoofaaru
# Processing Record 18 of Set 25 | ushuaia
# Processing Record 19 of Set 25 | kysyl-syr
# Processing Record 20 of Set 25 | myski
# Processing Record 21 of Set 25 | coihaique
# Processing Record 22 of Set 25 | hobart
# Processing Record 23 of Set 25 | jamestown
# Processing Record 24 of Set 25 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 25 | mataura
# Processing Record 26 of Set 25 | caravelas
# Processing Record 27 of Set 25 | jinchang
# Processing Record 28 of Set 25 | yellowknife
# No snow attribute found
# Processing Record 29 of Set 25 | mataura
# Processing Record 30 of Set 25 | cape town
# Processing Record 31 of Set 25 | sharjah
# Processing Record 32 of Set 25 | santo antonio do ica
# Processing Record 33 of Set 25 | hermanus
# Processing Record 34 of Set 25 | lavrentiya
# Processing Record 35 of Set 25 | tiksi
# Processing Record 36 of Set 25 | mount pleasant
# Processing Record 37 of Set 25 | goma
# Processing Record 38 of Set 25 | lebu
# Processing Record 39 of Set 25 | barrow
# Processing Record 40 of Set 25 | praia da vitoria
# Processing Record 41 of Set 25 | ushuaia
# Processing Record 42 of Set 25 | barrow
# Processing Record 43 of Set 25 | nanortalik
# Processing Record 44 of Set 25 | castro
# Processing Record 45 of Set 25 | georgetown
# Processing Record 46 of Set 25 | saskylakh
# Processing Record 47 of Set 25 | miri
# Processing Record 48 of Set 25 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 25 | kapaa
# Processing Record 50 of Set 25 | mangrol
# Processing Record 1 of Set 26 | busselton
# Processing Record 2 of Set 26 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 26 | tuktoyaktuk
# Processing Record 4 of Set 26 | bluff
# Processing Record 5 of Set 26 | punta arenas
# Processing Record 6 of Set 26 | shibarghan
# City not found. Skipping...
# Processing Record 7 of Set 26 | mataura
# Processing Record 8 of Set 26 | komsomolskiy
# Processing Record 9 of Set 26 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 26 | bluff
# Processing Record 11 of Set 26 | zemio
# Processing Record 12 of Set 26 | balatan
# Processing Record 13 of Set 26 | albany
# Processing Record 14 of Set 26 | margate
# Processing Record 15 of Set 26 | hermanus
# Processing Record 16 of Set 26 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 26 | hirara
# No rain attribute found
# Processing Record 18 of Set 26 | jamestown
# Processing Record 19 of Set 26 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 26 | tigzirt
# Processing Record 21 of Set 26 | semirom
# Processing Record 22 of Set 26 | touros
# Processing Record 23 of Set 26 | ginir
# Processing Record 24 of Set 26 | olinda
# Processing Record 25 of Set 26 | castro
# Processing Record 26 of Set 26 | airai
# Processing Record 27 of Set 26 | hilo
# No rain attribute found
# Processing Record 28 of Set 26 | avera
# Processing Record 29 of Set 26 | barrow
# Processing Record 30 of Set 26 | gladstone
# Processing Record 31 of Set 26 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 26 | bredasdorp
# Processing Record 33 of Set 26 | hermanus
# Processing Record 34 of Set 26 | chenghai
# Processing Record 35 of Set 26 | katobu
# Processing Record 36 of Set 26 | cooma
# Processing Record 37 of Set 26 | butaritari
# Processing Record 38 of Set 26 | mopipi
# Processing Record 39 of Set 26 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 26 | ushuaia
# Processing Record 41 of Set 26 | rikitea
# Processing Record 42 of Set 26 | sibolga
# Processing Record 43 of Set 26 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 26 | kroya
# Processing Record 45 of Set 26 | sao gabriel da cachoeira
# Processing Record 46 of Set 26 | marsala
# Processing Record 47 of Set 26 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 26 | vaini
# Processing Record 49 of Set 26 | cap malheureux
# Processing Record 50 of Set 26 | albany
# Processing Record 1 of Set 27 | punta arenas
# Processing Record 2 of Set 27 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 27 | albany
# Processing Record 4 of Set 27 | mataura
# Processing Record 5 of Set 27 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 27 | punta arenas
# Processing Record 7 of Set 27 | cape town
# Processing Record 8 of Set 27 | mataura
# Processing Record 9 of Set 27 | bluff
# Processing Record 10 of Set 27 | kruisfontein
# Processing Record 11 of Set 27 | kapiri mposhi
# Processing Record 12 of Set 27 | qaanaaq
# Processing Record 13 of Set 27 | zhezkazgan
# Processing Record 14 of Set 27 | benidorm
# Processing Record 15 of Set 27 | woodstock
# Processing Record 16 of Set 27 | codrington
# Processing Record 17 of Set 27 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 27 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 27 | faanui
# Processing Record 20 of Set 27 | sao miguel do araguaia
# Processing Record 21 of Set 27 | jamestown
# Processing Record 22 of Set 27 | puerto ayora
# Processing Record 23 of Set 27 | avera
# Processing Record 24 of Set 27 | mahebourg
# Processing Record 25 of Set 27 | cape town
# Processing Record 26 of Set 27 | krabi
# Processing Record 27 of Set 27 | qaanaaq
# Processing Record 28 of Set 27 | butaritari
# Processing Record 29 of Set 27 | khandyga
# Processing Record 30 of Set 27 | awjilah
# Processing Record 31 of Set 27 | nanakuli
# Processing Record 32 of Set 27 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 27 | tabas
# Processing Record 34 of Set 27 | cherskiy
# Processing Record 35 of Set 27 | arraial do cabo
# Processing Record 36 of Set 27 | punta arenas
# Processing Record 37 of Set 27 | ponta do sol
# Processing Record 38 of Set 27 | jaggayyapeta
# Processing Record 39 of Set 27 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 27 | port elizabeth
# Processing Record 41 of Set 27 | norman wells
# No snow attribute found
# Processing Record 42 of Set 27 | tuktoyaktuk
# Processing Record 43 of Set 27 | hermanus
# Processing Record 44 of Set 27 | ushuaia
# Processing Record 45 of Set 27 | atyrau
# Processing Record 46 of Set 27 | souillac
# Processing Record 47 of Set 27 | bethel
# No rain attribute found
# Processing Record 48 of Set 27 | vaini
# Processing Record 49 of Set 27 | chuy
# Processing Record 50 of Set 27 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 28 | lucieni
# Processing Record 2 of Set 28 | prabumulih
# Processing Record 3 of Set 28 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 28 | bambous virieux
# Processing Record 5 of Set 28 | nalut
# Processing Record 6 of Set 28 | paragominas
# Processing Record 7 of Set 28 | cidreira
# Processing Record 8 of Set 28 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 28 | ushuaia
# Processing Record 10 of Set 28 | mataura
# Processing Record 11 of Set 28 | tortoli
# Processing Record 12 of Set 28 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 28 | samoded
# Processing Record 14 of Set 28 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 28 | rikitea
# Processing Record 16 of Set 28 | ambilobe
# Processing Record 17 of Set 28 | albany
# Processing Record 18 of Set 28 | rikitea
# Processing Record 19 of Set 28 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 28 | bilma
# Processing Record 21 of Set 28 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 28 | hervey bay
# Processing Record 23 of Set 28 | tilichiki
# Processing Record 24 of Set 28 | nikolskoye
# Processing Record 25 of Set 28 | plettenberg bay
# Processing Record 26 of Set 28 | luderitz
# Processing Record 27 of Set 28 | bredasdorp
# Processing Record 28 of Set 28 | butaritari
# Processing Record 29 of Set 28 | hirado
# Processing Record 30 of Set 28 | sur
# Processing Record 31 of Set 28 | bredasdorp
# Processing Record 32 of Set 28 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 28 | kavieng
# Processing Record 34 of Set 28 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 28 | kaka
# Processing Record 36 of Set 28 | khatanga
# Processing Record 37 of Set 28 | rikitea
# Processing Record 38 of Set 28 | busselton
# Processing Record 39 of Set 28 | fortuna
# Processing Record 40 of Set 28 | campbell river
# Processing Record 41 of Set 28 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 28 | hokitika
# Processing Record 43 of Set 28 | buala
# Processing Record 44 of Set 28 | ushuaia
# Processing Record 45 of Set 28 | nemuro
# Processing Record 46 of Set 28 | lebu
# Processing Record 47 of Set 28 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 28 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 28 | la motte-servolex
# Processing Record 50 of Set 28 | tual
# Processing Record 1 of Set 29 | ilulissat
# Processing Record 2 of Set 29 | rikitea
# Processing Record 3 of Set 29 | winnemucca
# Processing Record 4 of Set 29 | cherskiy
# Processing Record 5 of Set 29 | mar del plata
# Processing Record 6 of Set 29 | rikitea
# Processing Record 7 of Set 29 | buala
# Processing Record 8 of Set 29 | castro
# Processing Record 9 of Set 29 | lufilufi

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Busselton -33.65  115.33     88.00        19           0       12.03
# 1          Faya  18.39   42.45     60.80        37           5        5.79
# 2       Rikitea -23.12 -134.97     79.43        84         100       20.51
# 3    Chokurdakh  70.63  147.92      0.88        83          93       13.76
# 4  Port Hedland -20.32  118.57     93.20        56          19       13.87
# 5     Hithadhoo  -0.60   73.08     84.81        63          64        5.66
# 6      Klaksvik  62.23   -6.59     35.60        80          83        8.05
# 7  Punta Arenas -53.15  -70.92     50.00        76          75        8.05
# 8         Vaini -21.20 -175.20     82.40        78          20        6.93
# 9     Jamestown  42.10  -79.24     45.00       100          90        8.05
#
#   Country Current Description  Rain inches(last 3hrs)  Snow inches(last 3hrs)  \
# 0      AU               Clear                    0.00                     0.0
# 1      SA               Clear                    0.00                     0.0
# 2      PF                Rain                    2.31                     0.0
# 3      RU              Clouds                    0.00                     0.0
# 4      AU              Clouds                    0.00                     0.0
# 5      MV              Clouds                    0.00                     0.0
# 6      FO              Clouds                    0.00                     0.0
# 7      CL              Clouds                    0.00                     0.0
# 8      TO              Clouds                    0.00                     0.0
# 9      US                 Fog                    0.00                     0.0
#
#                   Date
# 0  2020-03-03 05:24:21
# 1  2020-03-03 05:24:21
# 2  2020-03-03 05:23:03
# 3  2020-03-03 05:24:22
# 4  2020-03-03 05:24:22
# 5  2020-03-03 05:24:22
# 6  2020-03-03 05:24:22
# 7  2020-03-03 05:24:22
# 8  2020-03-03 05:24:23
# 9  2020-03-03 05:21:44

# %%
columns = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description",
          "Rain inches(last 3hrs)", "Snow inches(last 3hrs)"]
city_data_df = city_data_df[columns]
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0     Busselton      AU  2020-03-03 05:24:21 -33.65  115.33     88.00
# 1          Faya      SA  2020-03-03 05:24:21  18.39   42.45     60.80
# 2       Rikitea      PF  2020-03-03 05:23:03 -23.12 -134.97     79.43
# 3    Chokurdakh      RU  2020-03-03 05:24:22  70.63  147.92      0.88
# 4  Port Hedland      AU  2020-03-03 05:24:22 -20.32  118.57     93.20
# 5     Hithadhoo      MV  2020-03-03 05:24:22  -0.60   73.08     84.81
# 6      Klaksvik      FO  2020-03-03 05:24:22  62.23   -6.59     35.60
# 7  Punta Arenas      CL  2020-03-03 05:24:22 -53.15  -70.92     50.00
# 8         Vaini      TO  2020-03-03 05:24:23 -21.20 -175.20     82.40
# 9     Jamestown      US  2020-03-03 05:21:44  42.10  -79.24     45.00
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        19           0       12.03               Clear
# 1        37           5        5.79               Clear
# 2        84         100       20.51                Rain
# 3        83          93       13.76              Clouds
# 4        56          19       13.87              Clouds
# 5        63          64        5.66              Clouds
# 6        80          83        8.05              Clouds
# 7        76          75        8.05              Clouds
# 8        78          20        6.93              Clouds
# 9       100          90        8.05                 Fog
#
#    Rain inches(last 3hrs)  Snow inches(last 3hrs)
# 0                    0.00                     0.0
# 1                    0.00                     0.0
# 2                    2.31                     0.0
# 3                    0.00                     0.0
# 4                    0.00                     0.0
# 5                    0.00                     0.0
# 6                    0.00                     0.0
# 7                    0.00                     0.0
# 8                    0.00                     0.0
# 9                    0.00                     0.0

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c0257e359d83> in <module>
#       2 output_data_file = "data/WeatherPy_challenge.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# NameError: name 'city_data_df' is not defined

# %%
rain_cities = city_data_df.loc[(city_data_df["Rain inches(last 3hrs)"] > 0)]
snow_cities = city_data_df.loc[(city_data_df["Snow inches(last 3hrs)"] > 0)]
rain_or_snow_cities = city_data_df.loc[(city_data_df["Rain inches(last 3hrs)"] > 0) 
                                       |(city_data_df["Snow inches(last 3hrs)"] > 0)]
rain_or_snow_cities.head()
# Out:
#        City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 2   Rikitea      PF  2020-03-03 05:23:03 -23.12 -134.97     79.43        84
# 23   Dikson      RU  2020-03-03 05:24:26  73.51   80.55      7.02        95
# 25  Dunedin      NZ  2020-03-03 05:24:27 -45.87  170.50     57.99        85
# 26  Rikitea      PF  2020-03-03 05:23:03 -23.12 -134.97     79.43        84
# 31  Mataura      NZ  2020-03-03 05:24:28 -46.19  168.86     60.01        69
#
#     Cloudiness  Wind Speed Current Description  Rain inches(last 3hrs)  \
# 2          100       20.51                Rain                    2.31
# 23         100        5.30                Snow                    0.00
# 25          98        5.39                Rain                    0.75
# 26         100       20.51                Rain                    2.31
# 31          71       21.99                Rain                    0.13
#
#     Snow inches(last 3hrs)
# 2                     0.00
# 23                    0.13
# 25                    0.00
# 26                    0.00
# 31                    0.00

# %%
rain_cities.head()
# Out:
#        City Country                 Date    Lat     Lng  Max Temp  Humidity  \
# 2   Rikitea      PF  2020-03-03 05:23:03 -23.12 -134.97     79.43        84
# 25  Dunedin      NZ  2020-03-03 05:24:27 -45.87  170.50     57.99        85
# 26  Rikitea      PF  2020-03-03 05:23:03 -23.12 -134.97     79.43        84
# 31  Mataura      NZ  2020-03-03 05:24:28 -46.19  168.86     60.01        69
# 35  Rikitea      PF  2020-03-03 05:23:03 -23.12 -134.97     79.43        84
#
#     Cloudiness  Wind Speed Current Description  Rain inches(last 3hrs)  \
# 2          100       20.51                Rain                    2.31
# 25          98        5.39                Rain                    0.75
# 26         100       20.51                Rain                    2.31
# 31          71       21.99                Rain                    0.13
# 35         100       20.51                Rain                    2.31
#
#     Snow inches(last 3hrs)
# 2                      0.0
# 25                     0.0
# 26                     0.0
# 31                     0.0
# 35                     0.0

# %%
snow_cities.head()
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 23       Dikson      RU  2020-03-03 05:24:26  73.51   80.55      7.02
# 61    Ostrovnoy      RU  2020-03-03 05:24:35  68.05   39.51     24.35
# 66        Alihe      CN  2020-03-03 05:24:36  50.57  123.72     23.14
# 156        Hofn      IS  2020-03-03 05:24:56  64.25  -15.21     34.99
# 219  Turukhansk      RU  2020-03-03 05:25:10  65.82   87.98     14.22
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 23         95         100        5.30                Snow
# 61         95         100       20.18                Snow
# 66         77         100        3.51                Snow
# 156        95         100       39.39                Snow
# 219        94         100       11.41                Snow
#
#      Rain inches(last 3hrs)  Snow inches(last 3hrs)
# 23                      0.0                    0.13
# 61                      0.0                    0.88
# 66                      0.0                    0.56
# 156                     0.0                    1.06
# 219                     0.0                    0.69

# %%
# Rainfall or Snow recorded cities count
rain_or_snow_cities.count()
# Out:
# City                      222
# Country                   222
# Date                      222
# Lat                       222
# Lng                       222
# Max Temp                  222
# Humidity                  222
# Cloudiness                222
# Wind Speed                222
# Current Description       222
# Rain inches(last 3hrs)    222
# Snow inches(last 3hrs)    222
# dtype: int64

# %%
#Rainfall recorded cities count
rain_cities.count()
# Out:
# City                      198
# Country                   198
# Date                      198
# Lat                       198
# Lng                       198
# Max Temp                  198
# Humidity                  198
# Cloudiness                198
# Wind Speed                198
# Current Description       198
# Rain inches(last 3hrs)    198
# Snow inches(last 3hrs)    198
# dtype: int64

# %%
#Snow recorded cities count
snow_cities.count()
# Out:
# City                      24
# Country                   24
# Date                      24
# Lat                       24
# Lng                       24
# Max Temp                  24
# Humidity                  24
# Cloudiness                24
# Wind Speed                24
# Current Description       24
# Rain inches(last 3hrs)    24
# Snow inches(last 3hrs)    24
# dtype: int64
